# %% [markdown]
# <a href="https://colab.research.google.com/github/Nattarg/Linguistica-Computacional/blob/master/Linguistica-Computacional/1%20-%20Introdu%C3%A7%C3%A3o%20a%20Python%20(Lingu%C3%ADstica%20Computacional)/Exerc%C3%ADcios_Aula_01_Introdu%C3%A7%C3%A3o_a_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lista de Exercícios - Aula 1

# %% [markdown]
# ### 1. Elabore um algoritmo que escreva na tela "Estou começando a programar em Python!".
#
# ### 2. Elabore um algoritmo que receba dois números inteiros e exiba o resultado da soma desses números.
#
# ### 3.  Elabore um algoritmo que receba o nome do filme que o usuário mais gosta e retorne " O filme que você mais gosta é : xxxx".
#
# ### 4. Elabore um algoritmo que tranforme um valor em metros para milimetros.
#
# ### 5. Elabore um algoritmo que receba o nome do usuário e retorne verdadeiro se o nome do usuário começar com Ana ou ana.
